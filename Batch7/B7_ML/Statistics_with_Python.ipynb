# %% [markdown]
# <a href="https://colab.research.google.com/github/angelaaaateng/ftw_python/blob/main/Statistics_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Statistics with Python

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load Dataset
#
# For this exercise, we will be using the same dataset that you used in your data visualization class last week.

# %%
world_df = pd.read_csv('https://raw.githubusercontent.com/angelaaaateng/ftw_python/main/data/Data_Extract_From_World_Development_Indicators.csv')
world_df
# Out:
#           Country Name Country Code  \
# 0    Brunei Darussalam          BRN
# 1    Brunei Darussalam          BRN
# 2    Brunei Darussalam          BRN
# 3    Brunei Darussalam          BRN
# 4    Brunei Darussalam          BRN
# ..                 ...          ...
# 815          Indonesia          IDN
# 816          Indonesia          IDN
# 817          Indonesia          IDN
# 818          Indonesia          IDN
# 819          Indonesia          IDN
#
#                                            Series Name        Series Code  \
# 0              Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 1    Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 2    Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 3     Individuals using the Internet (% of population)     IT.NET.USER.ZS
# 4              Air transport, freight (million ton-km)  IS.AIR.GOOD.MT.K1
# ..                                                 ...                ...
# ...

# %%
world_df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]',
#        '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]',
#        '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]'],
#       dtype='object')

# %% [markdown]
# ## Describing our dataset with numbers

# %% [markdown]
# ### What is the overall sex distribution of primary educators?
#
# Based on the metadata table, we can check the code `SE.PRM.TCHR.FE.ZS`
#
# Here we'll likely look at average % of females, ranges among the countries, among the years

# %%
world_df['Series Code'].value_counts()
# Out:
# EG.ELC.ACCS.ZS       10
# SP.POP.0004.FE.5Y    10
# SP.POP.0014.TO.ZS    10
# SH.STA.BASS.UR.ZS    10
# SH.STA.BASS.ZS       10
#                      ..
# SE.PRM.TCHR          10
# SE.PRM.ENRL.FE.ZS    10
# SE.PRM.ENRL          10
# SE.PRM.DURS          10
# EN.POP.SLUM.UR.ZS    10
# Name: Series Code, Length: 82, dtype: int64

# %%
primary_educators_female = world_df[world_df['Series Code'] == 'SE.PRM.TCHR.FE.ZS']
primary_educators_female
# Out:
#           Country Name Country Code                             Series Name  \
# 27   Brunei Darussalam          BRN  Primary education, teachers (% female)
# 109           Cambodia          KHM  Primary education, teachers (% female)
# 191            Lao PDR          LAO  Primary education, teachers (% female)
# 273           Malaysia          MYS  Primary education, teachers (% female)
# 355            Myanmar          MMR  Primary education, teachers (% female)
# 437        Philippines          PHL  Primary education, teachers (% female)
# 519          Singapore          SGP  Primary education, teachers (% female)
# 601           Thailand          THA  Primary education, teachers (% female)
# 683            Vietnam          VNM  Primary education, teachers (% female)
# 765          Indonesia          IDN  Primary education, teachers (% female)
#
#            Series Code 2010 [YR2010] 2011 [YR2011] 2012 [YR2012]  \
# 27   SE.PRM.TCHR.FE.ZS   75.92401886   75.83528137    75.7305603
# ...

# %%
primary_educators_female.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 27 to 765
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   10 non-null     object
#  1   Country Code   10 non-null     object
#  2   Series Name    10 non-null     object
#  3   Series Code    10 non-null     object
#  4   2010 [YR2010]  10 non-null     object
#  5   2011 [YR2011]  10 non-null     object
#  6   2012 [YR2012]  10 non-null     object
#  7   2013 [YR2013]  10 non-null     object
#  8   2014 [YR2014]  10 non-null     object
#  9   2015 [YR2015]  10 non-null     object
#  10  2016 [YR2016]  10 non-null     object
#  11  2017 [YR2017]  10 non-null     object
#  12  2018 [YR2018]  10 non-null     object
#  13  2019 [YR2019]  10 non-null     object
#  14  2020 [YR2020]  10 non-null     object
# dtypes: object(15)
# memory usage: 1.2+ KB

# %%
# Assumption: we can replace 'null' values with 0, for simplification 

primary_educators_female  = primary_educators_female.replace("..", "0")
primary_educators_female
# Out:
#           Country Name Country Code                             Series Name  \
# 27   Brunei Darussalam          BRN  Primary education, teachers (% female)
# 109           Cambodia          KHM  Primary education, teachers (% female)
# 191            Lao PDR          LAO  Primary education, teachers (% female)
# 273           Malaysia          MYS  Primary education, teachers (% female)
# 355            Myanmar          MMR  Primary education, teachers (% female)
# 437        Philippines          PHL  Primary education, teachers (% female)
# 519          Singapore          SGP  Primary education, teachers (% female)
# 601           Thailand          THA  Primary education, teachers (% female)
# 683            Vietnam          VNM  Primary education, teachers (% female)
# 765          Indonesia          IDN  Primary education, teachers (% female)
#
#            Series Code 2010 [YR2010] 2011 [YR2011] 2012 [YR2012]  \
# 27   SE.PRM.TCHR.FE.ZS   75.92401886   75.83528137    75.7305603
# ...

# %%
# primary_educators_female.columns
cols_to_avg = [
       '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]',
       '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]',
       '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]']

# %%
primary_educators_female[cols_to_avg] = primary_educators_female[cols_to_avg].apply(pd.to_numeric, errors='coerce')
primary_educators_female[cols_to_avg].dtypes
# Out:
# 2010 [YR2010]    float64
# 2011 [YR2011]    float64
# 2012 [YR2012]    float64
# 2013 [YR2013]    float64
# 2014 [YR2014]    float64
# 2015 [YR2015]    float64
# 2016 [YR2016]    float64
# 2017 [YR2017]    float64
# 2018 [YR2018]    float64
# 2019 [YR2019]    float64
# 2020 [YR2020]      int64
# dtype: object

# %%
primary_educators_female.describe()
# Out:
#        2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# count      10.000000      10.000000      10.000000      10.000000
# mean       52.532794      44.384920      44.539367      38.522202
# std        30.066164      32.015789      32.084156      34.337938
# min         0.000000       0.000000       0.000000       0.000000
# 25%        47.446604      11.878893      12.232822       0.000000
# 50%        60.808451      55.514469      55.260786      50.302099
# 75%        74.119524      67.761932      67.805838      67.429210
# max        83.848381      77.121429      77.411522      76.748672
#
#        2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  \
# count      10.000000      10.000000      10.000000      10.000000
# mean       55.643689      49.002922      71.620214      64.410004
# std        31.739990      35.518067      11.966533      25.219237
# min         0.000000       0.000000      51.753578       0.000000
# ...

# %%
# Average % of females by country (row average)
primary_educators_female = primary_educators_female[['Country Name',
       '2010 [YR2010]', '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]',
       '2014 [YR2014]', '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]',
       '2018 [YR2018]', '2019 [YR2019]', '2020 [YR2020]']]
primary_educators_female
# Out:
#           Country Name  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  \
# 27   Brunei Darussalam      75.924019      75.835281      75.730560
# 109           Cambodia      46.218948      47.515572      48.931290
# 191            Lao PDR      51.129570      51.840599      50.840851
# 273           Malaysia      68.706039      69.349876      69.212311
# 355            Myanmar      83.848381       0.000000       0.000000
# 437        Philippines       0.000000       0.000000       0.000000
# 519          Singapore       0.000000       0.000000       0.000000
# 601           Thailand      59.150791      59.188339      59.680721
# 683            Vietnam      77.884079      77.121429      77.411522
# 765          Indonesia      62.466110      62.998100      63.586418
#
#      2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  \
# 27       76.748672      76.698303      77.312172      77.551018
# 109      50.005268      51.173180      53.321770      55.240250
# ...

# %%
primary_educators_female.mean()
# Out:
# <ipython-input-92-40dd78e30722>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   primary_educators_female.mean()
# 2010 [YR2010]    52.532794
# 2011 [YR2011]    44.384920
# 2012 [YR2012]    44.539367
# 2013 [YR2013]    38.522202
# 2014 [YR2014]    55.643689
# 2015 [YR2015]    49.002922
# 2016 [YR2016]    71.620214
# 2017 [YR2017]    64.410004
# 2018 [YR2018]    65.197124
# 2019 [YR2019]    47.565001
# 2020 [YR2020]     0.000000
# dtype: float64

# %%
primary_educators_female.set_index('Country Name', inplace=True)

# %%
primary_educators_female
# Out:
#                    2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# Country Name
# Brunei Darussalam      75.924019      75.835281      75.730560      76.748672
# Cambodia               46.218948      47.515572      48.931290      50.005268
# Lao PDR                51.129570      51.840599      50.840851      50.598930
# Malaysia               68.706039      69.349876      69.212311      69.099457
# Myanmar                83.848381       0.000000       0.000000       0.000000
# Philippines             0.000000       0.000000       0.000000       0.000000
# Singapore               0.000000       0.000000       0.000000       0.000000
# Thailand               59.150791      59.188339      59.680721       0.000000
# Vietnam                77.884079      77.121429      77.411522      76.351219
# Indonesia              62.466110      62.998100      63.586418      62.418468
#
#                    2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  \
# Country Name
# ...

# %%
primary_educators_female.mean(axis=1)
# Out:
# Country Name
# Brunei Darussalam    69.922399
# Cambodia             47.696670
# Lao PDR              46.960443
# Malaysia             63.123959
# Myanmar              37.551179
# Philippines          39.731371
# Singapore            21.958190
# Thailand             42.356488
# Vietnam              63.162826
# Indonesia            52.462145
# dtype: float64

# %%
primary_educators_female.describe()
# Out:
#        2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# count      10.000000      10.000000      10.000000      10.000000
# mean       52.532794      44.384920      44.539367      38.522202
# std        30.066164      32.015789      32.084156      34.337938
# min         0.000000       0.000000       0.000000       0.000000
# 25%        47.446604      11.878893      12.232822       0.000000
# 50%        60.808451      55.514469      55.260786      50.302099
# 75%        74.119524      67.761932      67.805838      67.429210
# max        83.848381      77.121429      77.411522      76.748672
#
#        2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  \
# count      10.000000      10.000000      10.000000      10.000000
# mean       55.643689      49.002922      71.620214      64.410004
# std        31.739990      35.518067      11.966533      25.219237
# min         0.000000       0.000000      51.753578       0.000000
# ...

# %%
primary_educators_female.apply(pd.Series.describe, axis=1)
# Out:
#                    count       mean        std  min        25%        50%  \
# Country Name
# Brunei Darussalam   11.0  69.922399  23.204907  0.0  75.879650  76.748672
# Cambodia            11.0  47.696670  16.338490  0.0  48.223431  51.173180
# Lao PDR             11.0  46.960443  15.597711  0.0  50.894875  51.266830
# Malaysia            11.0  63.123959  20.938486  0.0  69.155884  69.506630
# Myanmar             11.0  37.551179  43.153016  0.0   0.000000   0.000000
# Philippines         11.0  39.731371  45.648160  0.0   0.000000   0.000000
# Singapore           11.0  21.958190  37.607744  0.0   0.000000   0.000000
# Thailand            11.0  42.356488  33.990772  0.0   0.000000  59.188339
# Vietnam             11.0  63.162826  31.242158  0.0  75.586224  77.411522
# Indonesia           11.0  52.462145  26.026727  0.0  62.076685  62.466110
#
#                          75%        max
# Country Name
# Brunei Darussalam  77.515869  78.076729
# Cambodia           55.930836  58.177910
# ...

# %% [markdown]
# ## Tables and Pivot Tables in Python

# %% [markdown]
# ### 1. In 2014, which of the countries in the dataset had the highest overall Access to Electricity (% per population)?
#
# Here, we can use the code: `EG.ELC.ACCS.ZS`

# %%
electricity = world_df[world_df['Series Code'] == 'EG.ELC.ACCS.ZS']
electricity
# Out:
#           Country Name Country Code                              Series Name  \
# 0    Brunei Darussalam          BRN  Access to electricity (% of population)
# 82            Cambodia          KHM  Access to electricity (% of population)
# 164            Lao PDR          LAO  Access to electricity (% of population)
# 246           Malaysia          MYS  Access to electricity (% of population)
# 328            Myanmar          MMR  Access to electricity (% of population)
# 410        Philippines          PHL  Access to electricity (% of population)
# 492          Singapore          SGP  Access to electricity (% of population)
# 574           Thailand          THA  Access to electricity (% of population)
# 656            Vietnam          VNM  Access to electricity (% of population)
# 738          Indonesia          IDN  Access to electricity (% of population)
#
#         Series Code 2010 [YR2010] 2011 [YR2011] 2012 [YR2012] 2013 [YR2013]  \
# ...

# %%
electricity = electricity.replace("..", "0")
electricity[cols_to_avg] = electricity[cols_to_avg].apply(pd.to_numeric, errors='coerce')
electricity.dtypes
# Out:
# Country Name      object
# Country Code      object
# Series Name       object
# Series Code       object
# 2010 [YR2010]    float64
# 2011 [YR2011]    float64
# 2012 [YR2012]    float64
# 2013 [YR2013]    float64
# 2014 [YR2014]    float64
# 2015 [YR2015]    float64
# 2016 [YR2016]    float64
# 2017 [YR2017]    float64
# 2018 [YR2018]    float64
# 2019 [YR2019]    float64
# 2020 [YR2020]      int64
# dtype: object

# %%
electricity[['Country Name', '2014 [YR2014]']]
# Out:
#           Country Name  2014 [YR2014]
# 0    Brunei Darussalam     100.000000
# 82            Cambodia      56.100000
# 164            Lao PDR      83.179230
# 246           Malaysia      99.988358
# 328            Myanmar      52.000000
# 410        Philippines      89.692139
# 492          Singapore     100.000000
# 574           Thailand      99.483643
# 656            Vietnam      99.200000
# 738          Indonesia      97.010000

# %%
electricity[['Country Name', '2014 [YR2014]']].sort_values(by='2014 [YR2014]', ascending=False)
# Out:
#           Country Name  2014 [YR2014]
# 0    Brunei Darussalam     100.000000
# 492          Singapore     100.000000
# 246           Malaysia      99.988358
# 574           Thailand      99.483643
# 656            Vietnam      99.200000
# 738          Indonesia      97.010000
# 410        Philippines      89.692139
# 164            Lao PDR      83.179230
# 82            Cambodia      56.100000
# 328            Myanmar      52.000000

# %% [markdown]
# ###  2. Which year had the highest % of population living in slums per country?

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-98-ded5ba42480f> in <module>
# ----> 1 s
#
# NameError: name 's' is not defined

# %%
import seaborn as sns

# Load the data into a pandas DataFrame
data = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv")

# View the first few rows of the data
data.head()

# Calculate some basic statistics for the data
data.describe()

# Create a visualization of the data using seaborn
sns.scatterplot(x="gdpPercap", y="lifeExp", hue="continent", data=data)
